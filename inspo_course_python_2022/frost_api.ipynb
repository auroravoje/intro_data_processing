# %%
# Libraries needed (pandas is not standard and must be installed in Python)
import requests
import pandas as pd

# Insert your own client ID here
client_id = 'ab77804f-a2da-4fa2-b58e-c9983aed8387'

# %%
# Define endpoint and parameters
endpoint = 'https://frost.met.no/observations/v0.jsonld'
parameters = {
    'sources': 'SN18700,SN90450',
    'elements': 'mean(air_temperature P1D),sum(precipitation_amount P1D),mean(wind_speed P1D)',
    'referencetime': '2010-04-01/2010-04-03',
}
# Issue an HTTP GET request
r = requests.get(endpoint, parameters, auth=(client_id,''))
# Extract JSON data
json = r.json()

# %%
json
# Out:
# {'@context': 'https://frost.met.no/schema',
#  '@type': 'ObservationResponse',
#  'apiVersion': 'v0',
#  'license': 'https://creativecommons.org/licenses/by/3.0/no/',
#  'createdAt': '2022-10-06T11:47:18Z',
#  'queryTime': 0.387,
#  'currentItemCount': 4,
#  'itemsPerPage': 4,
#  'offset': 0,
#  'totalItemCount': 4,
#  'currentLink': 'https://frost.met.no/observations/v0.jsonld?sources=SN18700%2CSN90450&elements=mean%28air_temperature+P1D%29%2Csum%28precipitation_amount+P1D%29%2Cmean%28wind_speed+P1D%29&referencetime=2010-04-01%2F2010-04-03',
#  'data': [{'sourceId': 'SN18700:0',
#    'referenceTime': '2010-04-01T00:00:00.000Z',
#    'observations': [{'elementId': 'mean(air_temperature P1D)',
#      'value': 3.2,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'C',
#      'exposureCategory': '2',
#      'qualityCode': 2},
#     {'elementId': 'mean(air_temperature P1D)',
#      'value': 3,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'C',
#      'exposureCategory': '2',
#      'qualityCode': 2},
#     {'elementId': 'sum(precipitation_amount P1D)',
#      'value': 13.5,
#      'unit': 'mm',
#      'timeOffset': 'PT18H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'C',
#      'exposureCategory': '2',
#      'qualityCode': 2},
#     {'elementId': 'sum(precipitation_amount P1D)',
#      'value': 29,
#      'unit': 'mm',
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'C',
#      'exposureCategory': '2',
#      'qualityCode': 2},
#     {'elementId': 'mean(wind_speed P1D)',
#      'value': 1.7,
#      'unit': 'm/s',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'C',
#      'exposureCategory': '2',
#      'qualityCode': 2}]},
#   {'sourceId': 'SN18700:0',
#    'referenceTime': '2010-04-02T00:00:00.000Z',
#    'observations': [{'elementId': 'mean(air_temperature P1D)',
#      'value': 3,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'C',
#      'exposureCategory': '2',
#      'qualityCode': 2},
#     {'elementId': 'mean(air_temperature P1D)',
#      'value': 3.2,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'C',
#      'exposureCategory': '2',
#      'qualityCode': 2},
#     {'elementId': 'sum(precipitation_amount P1D)',
#      'value': 3.3,
#      'unit': 'mm',
#      'timeOffset': 'PT18H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'C',
#      'exposureCategory': '2',
#      'qualityCode': 2},
#     {'elementId': 'sum(precipitation_amount P1D)',
#      'value': 9,
#      'unit': 'mm',
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'C',
#      'exposureCategory': '2',
#      'qualityCode': 2},
#     {'elementId': 'mean(wind_speed P1D)',
#      'value': 2.9,
#      'unit': 'm/s',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'C',
#      'exposureCategory': '2',
#      'qualityCode': 2}]},
#   {'sourceId': 'SN90450:0',
#    'referenceTime': '2010-04-01T00:00:00.000Z',
#    'observations': [{'elementId': 'mean(air_temperature P1D)',
#      'value': 2.1,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'C',
#      'exposureCategory': '2',
#      'qualityCode': 2},
#     {'elementId': 'mean(air_temperature P1D)',
#      'value': -0.9,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'C',
#      'exposureCategory': '2',
#      'qualityCode': 2},
#     {'elementId': 'sum(precipitation_amount P1D)',
#      'value': 0,
#      'unit': 'mm',
#      'timeOffset': 'PT18H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'C',
#      'exposureCategory': '2',
#      'qualityCode': 2},
#     {'elementId': 'sum(precipitation_amount P1D)',
#      'value': 0,
#      'unit': 'mm',
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'C',
#      'exposureCategory': '2',
#      'qualityCode': 2},
#     {'elementId': 'mean(wind_speed P1D)',
#      'value': 1.3,
#      'unit': 'm/s',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'C',
#      'exposureCategory': '2',
#      'qualityCode': 2}]},
#   {'sourceId': 'SN90450:0',
#    'referenceTime': '2010-04-02T00:00:00.000Z',
#    'observations': [{'elementId': 'mean(air_temperature P1D)',
#      'value': 6.1,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'C',
#      'exposureCategory': '2',
#      'qualityCode': 2},
#     {'elementId': 'mean(air_temperature P1D)',
#      'value': 3.4,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'C',
#      'exposureCategory': '2',
#      'qualityCode': 2},
#     {'elementId': 'sum(precipitation_amount P1D)',
#      'value': 0,
#      'unit': 'mm',
#      'timeOffset': 'PT18H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'C',
#      'exposureCategory': '2',
#      'qualityCode': 2},
#     {'elementId': 'sum(precipitation_amount P1D)',
#      'value': 0,
#      'unit': 'mm',
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'C',
#      'exposureCategory': '2',
#      'qualityCode': 2},
#     {'elementId': 'mean(wind_speed P1D)',
#      'value': 3.9,
#      'unit': 'm/s',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'C',
#      'exposureCategory': '2',
#      'qualityCode': 2}]}]}

# %%
# Check if the request worked, print out any errors
if r.status_code == 200:
    data = json['data']
    print('Data retrieved from frost.met.no!')
else:
    print('Error! Returned status code %s' % r.status_code)
    print('Message: %s' % json['error']['message'])
    print('Reason: %s' % json['error']['reason'])
# Out:
# Data retrieved from frost.met.no!

# %%
# This will return a Dataframe with all of the observations in a table format
df = pd.DataFrame()
for i in range(len(data)):
    row = pd.DataFrame(data[i]['observations'])
    row['referenceTime'] = data[i]['referenceTime']
    row['sourceId'] = data[i]['sourceId']
    df = df.append(row)

df = df.reset_index()
# Out:
# /var/folders/fs/7v5dx67d12zdj8zvnsv_vtmh0000gn/T/ipykernel_78023/805265779.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row)
# /var/folders/fs/7v5dx67d12zdj8zvnsv_vtmh0000gn/T/ipykernel_78023/805265779.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row)
# /var/folders/fs/7v5dx67d12zdj8zvnsv_vtmh0000gn/T/ipykernel_78023/805265779.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row)
# /var/folders/fs/7v5dx67d12zdj8zvnsv_vtmh0000gn/T/ipykernel_78023/805265779.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row)

# %%
df.head()
# Out:
#    index                      elementId  value  unit  \
# 0      0      mean(air_temperature P1D)    3.2  degC
# 1      1      mean(air_temperature P1D)    3.0  degC
# 2      2  sum(precipitation_amount P1D)   13.5    mm
# 3      3  sum(precipitation_amount P1D)   29.0    mm
# 4      4           mean(wind_speed P1D)    1.7   m/s
#
#                                                level timeOffset  \
# 0  {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 1  {'levelType': 'height_above_ground', 'unit': '...       PT6H
# 2                                                NaN      PT18H
# 3                                                NaN       PT6H
# 4  {'levelType': 'height_above_ground', 'unit': '...       PT0H
#
#   timeResolution  timeSeriesId performanceCategory exposureCategory  \
# 0            P1D             0                   C                2
# 1            P1D             0                   C                2
# 2            P1D             0                   C                2
# 3            P1D             0                   C                2
# 4            P1D             0                   C                2
#
#    qualityCode             referenceTime   sourceId
# 0            2  2010-04-01T00:00:00.000Z  SN18700:0
# 1            2  2010-04-01T00:00:00.000Z  SN18700:0
# 2            2  2010-04-01T00:00:00.000Z  SN18700:0
# 3            2  2010-04-01T00:00:00.000Z  SN18700:0
# 4            2  2010-04-01T00:00:00.000Z  SN18700:0
