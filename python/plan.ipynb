# %% [markdown]
# # Introduction to Data Processing With Python

# %% [markdown]
# - Introduction
# - Spyder
# - Read Excel Data
#     - Import `pandas`
#     - Read Excel data with `pandas`
#     - Inspect a `pandas` data frame
#     - Add parameters to read Excel data properly
#     - Rename columns/variables
#     - Exercise
# - Tidy Data
#     - Obervations and variables
#     - Melt messy data to create tidy data
#     - Visualizations
#     - Exercise
# - Process Data
#     - Handle missing values
#     - Select variables
#     - Combine variables
#     - Filter observations
#     - Sort observations
#     - Exercise
# - Aggregate Data
#     - Bigger datasets
#     - Date columns
#     - Group by common values
#     - Aggregations: sum, mean, first, median, count
#     - Exercise
# - Combine Data Tables
#     - Append tables of similar data
#     - Exercise
#     - Join tables with common variables
#     - Exercise
# - Sharing Insights
#     - Mess up data for presentation with pivot
#     - Save to Excel (and other formats)
#     - More visualizations

# %% [markdown]
# ## Read Excel Data

# %% [markdown]
# ### Importing packages

# %%
import pandas as pd

# %% [markdown]
# ### Read Excel data with pandas

# %%
pd.read_excel("../data/kap1.xlsx")
# Out:
#   Dette regnearket inneholder tallene bak figurene i   \
# 0  Kapittel 1 Hovedlinjer i den økonomiske politi...
# 1                                                NaN
# 2                                          Figur 1.1
# 3                                          Figur 1.2
#
#                                           Unnamed: 1
# 0                                                NaN
# 1                                                NaN
# 2  Samlet overskudd i statsbudsjettet og Statens ...
# 3  Finanspolitisk respons på virusutbruddet i utv...

# %%
pd.read_excel("../data/kap1.xlsx", sheet_name="1.2")
# Out:
#         Figur 1.2  \
# 0             NaN
# 1             NaN
# 2             NaN
# 3
# 4           India
# 5       Frankrike
# 6        Russland
# 7          Spania
# 8          Italia
# 9           Korea
# 10        Finland
# 11           Kina
# 12      Nederland
# 13         Brasil
# 14  Storbritannia
# 15        Sverige
# 16       Tyskland
# 17        Danmark
# 18          Norge
# 19         Canada
# 20            USA
# 21          Japan
# 22      Australia
#
#    Finanspolitisk respons på virusutbruddet i utvalgte land. \n  \
# 0                                         Pst. av BNP
# 1                                                 NaN
# 2                                                 NaN
# 3                                       Budsjettiltak
# 4                                                 0.7
# 5                                                 0.7
# 6                                                 0.9
# 7                                                 1.2
# 8                                                 1.2
# 9                                                 1.5
# 10                                                1.7
# 11                                                2.5
# 12                                                2.7
# 13                                                2.9
# 14                                                3.1
# 15                                                3.4
# 16                                                4.4
# 17                                                4.9
# 18                                                5.1
# 19                                                5.2
# 20                                                6.9
# 21                                                 10
# 22                                               10.6
#
#           Unnamed: 2
# 0                NaN
# 1                NaN
# 2                NaN
# 3   Lån og garantier
# 4                  0
# 5               13.9
# 6                0.6
# 7                9.8
# 8               32.4
# 9                6.4
# 10               5.4
# 11                 0
# 12                 -
# 13               4.2
# 14              15.7
# 15                 5
# 16              29.6
# 17               5.3
# 18                 4
# 19               3.3
# 20               4.2
# 21              10.4
# 22               1.9

# %% [markdown]
# ### Inspect pandas data frames

# %%
pd.read_excel("../data/kap1.xlsx", sheet_name="1.2").info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 3 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   Figur 1.2                                                    20 non-null     object
#  1   Finanspolitisk respons på virusutbruddet i utvalgte land.
#   21 non-null     object
#  2   Unnamed: 2                                                   20 non-null     object
# dtypes: object(3)
# memory usage: 680.0+ bytes

# %% [markdown]
# ### Add parameters to read Excel data properly

# %%
pd.read_excel("../data/kap1.xlsx", sheet_name="1.2", header=5)
# Out:
#             India   0.7     0
# 0       Frankrike   0.7  13.9
# 1        Russland   0.9   0.6
# 2          Spania   1.2   9.8
# 3          Italia   1.2  32.4
# 4           Korea   1.5   6.4
# 5         Finland   1.7   5.4
# 6            Kina   2.5     0
# 7       Nederland   2.7     -
# 8          Brasil   2.9   4.2
# 9   Storbritannia   3.1  15.7
# 10        Sverige   3.4     5
# 11       Tyskland   4.4  29.6
# 12        Danmark   4.9   5.3
# 13          Norge   5.1     4
# 14         Canada   5.2   3.3
# 15            USA   6.9   4.2
# 16          Japan  10.0  10.4
# 17      Australia  10.6   1.9

# %%
pd.read_excel("../data/kap1.xlsx", sheet_name="1.2", header=4)
# Out:
#                    Budsjettiltak Lån og garantier
# 0           India            0.7                0
# 1       Frankrike            0.7             13.9
# 2        Russland            0.9              0.6
# 3          Spania            1.2              9.8
# 4          Italia            1.2             32.4
# 5           Korea            1.5              6.4
# 6         Finland            1.7              5.4
# 7            Kina            2.5                0
# 8       Nederland            2.7                -
# 9          Brasil            2.9              4.2
# 10  Storbritannia            3.1             15.7
# 11        Sverige            3.4                5
# 12       Tyskland            4.4             29.6
# 13        Danmark            4.9              5.3
# 14          Norge            5.1                4
# 15         Canada            5.2              3.3
# 16            USA            6.9              4.2
# 17          Japan           10.0             10.4
# 18      Australia           10.6              1.9

# %%
budget = pd.read_excel("../data/kap1.xlsx", sheet_name="1.2", header=4)

# %%
budget.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0                     19 non-null     object
#  1   Budsjettiltak     19 non-null     float64
#  2   Lån og garantier  19 non-null     object
# dtypes: float64(1), object(2)
# memory usage: 584.0+ bytes

# %%
budget.loc[0]
# Out:
#                     India
# Budsjettiltak         0.7
# Lån og garantier        0
# Name: 0, dtype: object

# %%
budget.loc["Norge"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [10], line 1
# ----> 1 budget.loc["Norge"]
#
# File ~/.pyenv/versions/3.10.7/envs/kurs_ffi/lib/python3.10/site-packages/pandas/core/indexing.py:1074, in _LocationIndexer.__getitem__(self, key)
#    1071 axis = self.axis or 0
#    1073 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1074 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/.pyenv/versions/3.10.7/envs/kurs_ffi/lib/python3.10/site-packages/pandas/core/indexing.py:1313, in _LocIndexer._getitem_axis(self, key, axis)
#    1311 # fall thru to straight lookup
#    1312 self._validate_key(key, axis)
# -> 1313 return self._get_label(key, axis=axis)
#
# File ~/.pyenv/versions/3.10.7/envs/kurs_ffi/lib/python3.10/site-packages/pandas/core/indexing.py:1261, in _LocIndexer._get_label(self, label, axis)
#    1259 def _get_label(self, label, axis: int):
#    1260     # GH#5567 this will fail if the label is not present in the axis.
# -> 1261     return self.obj.xs(label, axis=axis)
#
# File ~/.pyenv/versions/3.10.7/envs/kurs_ffi/lib/python3.10/site-packages/pandas/core/generic.py:4057, in NDFrame.xs(self, key, axis, level, drop_level)
#    4055             new_index = index[loc]
#    4056 else:
# -> 4057     loc = index.get_loc(key)
#    4059     if isinstance(loc, np.ndarray):
#    4060         if loc.dtype == np.bool_:
#
# File ~/.pyenv/versions/3.10.7/envs/kurs_ffi/lib/python3.10/site-packages/pandas/core/indexes/range.py:396, in RangeIndex.get_loc(self, key, method, tolerance)
#     394             raise KeyError(key) from err
#     395     self._check_indexing_error(key)
# --> 396     raise KeyError(key)
#     397 return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: 'Norge'

# %%
pd.read_excel("../data/kap1.xlsx", sheet_name="1.2", header=4, index_col=0)
# Out:
#                Budsjettiltak Lån og garantier
#
# India                    0.7                0
# Frankrike                0.7             13.9
# Russland                 0.9              0.6
# Spania                   1.2              9.8
# Italia                   1.2             32.4
# Korea                    1.5              6.4
# Finland                  1.7              5.4
# Kina                     2.5                0
# Nederland                2.7                -
# Brasil                   2.9              4.2
# Storbritannia            3.1             15.7
# Sverige                  3.4                5
# Tyskland                 4.4             29.6
# Danmark                  4.9              5.3
# Norge                    5.1                4
# Canada                   5.2              3.3
# USA                      6.9              4.2
# Japan                   10.0             10.4
# Australia               10.6              1.9

# %%
budget = pd.read_excel("../data/kap1.xlsx", sheet_name="1.2", header=4, index_col=0)

# %%
budget.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19 entries, India to Australia
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Budsjettiltak     19 non-null     float64
#  1   Lån og garantier  19 non-null     object
# dtypes: float64(1), object(1)
# memory usage: 456.0+ bytes

# %%
budget.describe()
# Out:
#        Budsjettiltak
# count      19.000000
# mean        3.663158
# std         2.928445
# min         0.700000
# 25%         1.350000
# 50%         2.900000
# 75%         5.000000
# max        10.600000

# %%
budget.loc["Norge"]
# Out:
# Budsjettiltak       5.1
# Lån og garantier      4
# Name: Norge, dtype: object

# %%
budget.loc[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.7/envs/kurs_ffi/lib/python3.10/site-packages/pandas/core/indexes/base.py:3800, in Index.get_loc(self, key, method, tolerance)
#    3799 try:
# -> 3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
#
# File ~/.pyenv/versions/3.10.7/envs/kurs_ffi/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.pyenv/versions/3.10.7/envs/kurs_ffi/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [16], line 1
# ----> 1 budget.loc[0]
#
# File ~/.pyenv/versions/3.10.7/envs/kurs_ffi/lib/python3.10/site-packages/pandas/core/indexing.py:1074, in _LocationIndexer.__getitem__(self, key)
#    1071 axis = self.axis or 0
#    1073 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1074 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/.pyenv/versions/3.10.7/envs/kurs_ffi/lib/python3.10/site-packages/pandas/core/indexing.py:1313, in _LocIndexer._getitem_axis(self, key, axis)
#    1311 # fall thru to straight lookup
#    1312 self._validate_key(key, axis)
# -> 1313 return self._get_label(key, axis=axis)
#
# File ~/.pyenv/versions/3.10.7/envs/kurs_ffi/lib/python3.10/site-packages/pandas/core/indexing.py:1261, in _LocIndexer._get_label(self, label, axis)
#    1259 def _get_label(self, label, axis: int):
#    1260     # GH#5567 this will fail if the label is not present in the axis.
# -> 1261     return self.obj.xs(label, axis=axis)
#
# File ~/.pyenv/versions/3.10.7/envs/kurs_ffi/lib/python3.10/site-packages/pandas/core/generic.py:4057, in NDFrame.xs(self, key, axis, level, drop_level)
#    4055             new_index = index[loc]
#    4056 else:
# -> 4057     loc = index.get_loc(key)
#    4059     if isinstance(loc, np.ndarray):
#    4060         if loc.dtype == np.bool_:
#
# File ~/.pyenv/versions/3.10.7/envs/kurs_ffi/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
# -> 3802     raise KeyError(key) from err
#    3803 except TypeError:
#    3804     # If we have a listlike key, _check_indexing_error will raise
#    3805     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3806     #  the TypeError.
#    3807     self._check_indexing_error(key)
#
# KeyError: 0

# %%
budget.iloc[0]
# Out:
# Budsjettiltak       0.7
# Lån og garantier      0
# Name: India, dtype: object

# %%
budget.Budsjettiltak
# Out:
#
# India             0.7
# Frankrike         0.7
# Russland          0.9
# Spania            1.2
# Italia            1.2
# Korea             1.5
# Finland           1.7
# Kina              2.5
# Nederland         2.7
# Brasil            2.9
# Storbritannia     3.1
# Sverige           3.4
# Tyskland          4.4
# Danmark           4.9
# Norge             5.1
# Canada            5.2
# USA               6.9
# Japan            10.0
# Australia        10.6
# Name: Budsjettiltak, dtype: float64

# %%
budget.Lån og garantier
# Out:
#   Cell In [19], line 1
#     budget.Lån og garantier
#                ^
# SyntaxError: invalid syntax

# %%
budget["Lån og garantier"]
# Out:
#
# India               0
# Frankrike        13.9
# Russland          0.6
# Spania            9.8
# Italia           32.4
# Korea             6.4
# Finland           5.4
# Kina                0
# Nederland           -
# Brasil            4.2
# Storbritannia    15.7
# Sverige             5
# Tyskland         29.6
# Danmark           5.3
# Norge               4
# Canada            3.3
# USA               4.2
# Japan            10.4
# Australia         1.9
# Name: Lån og garantier, dtype: object

# %%
budget.loc[:, "Lån og garantier"]
# Out:
#
# India               0
# Frankrike        13.9
# Russland          0.6
# Spania            9.8
# Italia           32.4
# Korea             6.4
# Finland           5.4
# Kina                0
# Nederland           -
# Brasil            4.2
# Storbritannia    15.7
# Sverige             5
# Tyskland         29.6
# Danmark           5.3
# Norge               4
# Canada            3.3
# USA               4.2
# Japan            10.4
# Australia         1.9
# Name: Lån og garantier, dtype: object

# %%
pd.read_excel("../data/kap1.xlsx", sheet_name="1.2", header=4, index_col=0).rename(
    columns={"Budsjettiltak": "tiltak", "Lån og garantier": "lån"}
)
# Out:
#                tiltak   lån
#
# India             0.7     0
# Frankrike         0.7  13.9
# Russland          0.9   0.6
# Spania            1.2   9.8
# Italia            1.2  32.4
# Korea             1.5   6.4
# Finland           1.7   5.4
# Kina              2.5     0
# Nederland         2.7     -
# Brasil            2.9   4.2
# Storbritannia     3.1  15.7
# Sverige           3.4     5
# Tyskland          4.4  29.6
# Danmark           4.9   5.3
# Norge             5.1     4
# Canada            5.2   3.3
# USA               6.9   4.2
# Japan            10.0  10.4
# Australia        10.6   1.9

# %%
budget = pd.read_excel(
    "../data/kap1.xlsx", sheet_name="1.2", header=4, index_col=0
).rename(columns={"Budsjettiltak": "tiltak", "Lån og garantier": "lån"})

# %% [markdown]
# ### Exercise
#
# Read data from the file `r"..\data\driftsinntekter-2021.xls"` with `pandas`. Which parameters do you need to specify? Use the [`pandas` documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_excel.html) to look up available parameters.

# %%
pd.read_excel("../data/driftsinntekter-2021.xlsx", header=1)
# Out:
#                                  Category    2019   2020   2021
# 0                           Basistilskudd     216    203    202
# 1   Basistilskudd personell og kompetanse       -      -      3
# 2                      Forvaltningsmidler   307.7  196.9      -
# 3               Tilskudd H.U. Sverdrup II   284.3  274.2  200.1
# 4        Tilskudd Kjemiidentifikasjonslab   107.1   55.7   88.8
# 5                        CBRNE-satsningen       -      -     85
# 6                Tilskudd og overføringer   389.4  439.1  341.8
# 7                  Strategiske FoU-midler  2131.1   2109   2159
# 8     Konsept- og forprosjekteringsmidler   838.2  696.2  635.1
# 9                        Forsvarssektoren    3759   3988   5180
# 10   Sivile og offentlige, inn- og utland   678.1  979.6  761.4

# %% [markdown]
# ## Tidy Data
#
# ### Observations and variables
#
# Hadley Wickham introduced the term **tidy data** (<https://tidyr.tidyverse.org/articles/tidy-data.html>). Data tidying is a way to **structure DataFrames to facilitate analysis**.
#
# A DataFrame is tidy if:
#
# - Each variable is a column
# - Each observation is a row
# - Each DataFrame contains one observational unit
#
# Note that tidy data principles are closely tied to normalization of relational databases.

# %%
income = pd.read_excel("../data/driftsinntekter-2021.xlsx", header=1).rename(
    columns={"Category": "category"}
)
income
# Out:
#                                  category    2019   2020   2021
# 0                           Basistilskudd     216    203    202
# 1   Basistilskudd personell og kompetanse       -      -      3
# 2                      Forvaltningsmidler   307.7  196.9      -
# 3               Tilskudd H.U. Sverdrup II   284.3  274.2  200.1
# 4        Tilskudd Kjemiidentifikasjonslab   107.1   55.7   88.8
# 5                        CBRNE-satsningen       -      -     85
# 6                Tilskudd og overføringer   389.4  439.1  341.8
# 7                  Strategiske FoU-midler  2131.1   2109   2159
# 8     Konsept- og forprosjekteringsmidler   838.2  696.2  635.1
# 9                        Forsvarssektoren    3759   3988   5180
# 10   Sivile og offentlige, inn- og utland   678.1  979.6  761.4

# %% [markdown]
# Is the `income` data frame tidy?
#
# > No, _2019_, _2020_, and _2021_ are not variables. They are values of a _year_ variable

# %% [markdown]
# ### Melt messy datasets to tidy them

# %%
income.melt()
# Out:
#     variable                                  value
# 0   category                          Basistilskudd
# 1   category  Basistilskudd personell og kompetanse
# 2   category                     Forvaltningsmidler
# 3   category              Tilskudd H.U. Sverdrup II
# 4   category       Tilskudd Kjemiidentifikasjonslab
# 5   category                       CBRNE-satsningen
# 6   category               Tilskudd og overføringer
# 7   category                 Strategiske FoU-midler
# 8   category    Konsept- og forprosjekteringsmidler
# 9   category                       Forsvarssektoren
# 10  category   Sivile og offentlige, inn- og utland
# 11      2019                                    216
# 12      2019                                      -
# 13      2019                                  307.7
# 14      2019                                  284.3
# 15      2019                                  107.1
# 16      2019                                      -
# 17      2019                                  389.4
# 18      2019                                 2131.1
# 19      2019                                  838.2
# 20      2019                                   3759
# 21      2019                                  678.1
# 22      2020                                    203
# 23      2020                                      -
# 24      2020                                  196.9
# 25      2020                                  274.2
# 26      2020                                   55.7
# 27      2020                                      -
# 28      2020                                  439.1
# 29      2020                                   2109
# 30      2020                                  696.2
# 31      2020                                   3988
# 32      2020                                  979.6
# 33      2021                                    202
# 34      2021                                      3
# 35      2021                                      -
# 36      2021                                  200.1
# 37      2021                                   88.8
# 38      2021                                     85
# 39      2021                                  341.8
# 40      2021                                   2159
# 41      2021                                  635.1
# 42      2021                                   5180
# 43      2021                                  761.4

# %%
income.melt(id_vars=["category"])
# Out:
#                                  category variable   value
# 0                           Basistilskudd     2019     216
# 1   Basistilskudd personell og kompetanse     2019       -
# 2                      Forvaltningsmidler     2019   307.7
# 3               Tilskudd H.U. Sverdrup II     2019   284.3
# 4        Tilskudd Kjemiidentifikasjonslab     2019   107.1
# 5                        CBRNE-satsningen     2019       -
# 6                Tilskudd og overføringer     2019   389.4
# 7                  Strategiske FoU-midler     2019  2131.1
# 8     Konsept- og forprosjekteringsmidler     2019   838.2
# 9                        Forsvarssektoren     2019    3759
# 10   Sivile og offentlige, inn- og utland     2019   678.1
# 11                          Basistilskudd     2020     203
# 12  Basistilskudd personell og kompetanse     2020       -
# 13                     Forvaltningsmidler     2020   196.9
# 14              Tilskudd H.U. Sverdrup II     2020   274.2
# 15       Tilskudd Kjemiidentifikasjonslab     2020    55.7
# 16                       CBRNE-satsningen     2020       -
# 17               Tilskudd og overføringer     2020   439.1
# 18                 Strategiske FoU-midler     2020    2109
# 19    Konsept- og forprosjekteringsmidler     2020   696.2
# 20                       Forsvarssektoren     2020    3988
# 21   Sivile og offentlige, inn- og utland     2020   979.6
# 22                          Basistilskudd     2021     202
# 23  Basistilskudd personell og kompetanse     2021       3
# 24                     Forvaltningsmidler     2021       -
# 25              Tilskudd H.U. Sverdrup II     2021   200.1
# 26       Tilskudd Kjemiidentifikasjonslab     2021    88.8
# 27                       CBRNE-satsningen     2021      85
# 28               Tilskudd og overføringer     2021   341.8
# 29                 Strategiske FoU-midler     2021    2159
# 30    Konsept- og forprosjekteringsmidler     2021   635.1
# 31                       Forsvarssektoren     2021    5180
# 32   Sivile og offentlige, inn- og utland     2021   761.4

# %%
income.melt(id_vars=["category"], var_name="year")
# Out:
#                                  category  year   value
# 0                           Basistilskudd  2019     216
# 1   Basistilskudd personell og kompetanse  2019       -
# 2                      Forvaltningsmidler  2019   307.7
# 3               Tilskudd H.U. Sverdrup II  2019   284.3
# 4        Tilskudd Kjemiidentifikasjonslab  2019   107.1
# 5                        CBRNE-satsningen  2019       -
# 6                Tilskudd og overføringer  2019   389.4
# 7                  Strategiske FoU-midler  2019  2131.1
# 8     Konsept- og forprosjekteringsmidler  2019   838.2
# 9                        Forsvarssektoren  2019    3759
# 10   Sivile og offentlige, inn- og utland  2019   678.1
# 11                          Basistilskudd  2020     203
# 12  Basistilskudd personell og kompetanse  2020       -
# 13                     Forvaltningsmidler  2020   196.9
# 14              Tilskudd H.U. Sverdrup II  2020   274.2
# 15       Tilskudd Kjemiidentifikasjonslab  2020    55.7
# 16                       CBRNE-satsningen  2020       -
# 17               Tilskudd og overføringer  2020   439.1
# 18                 Strategiske FoU-midler  2020    2109
# 19    Konsept- og forprosjekteringsmidler  2020   696.2
# 20                       Forsvarssektoren  2020    3988
# 21   Sivile og offentlige, inn- og utland  2020   979.6
# 22                          Basistilskudd  2021     202
# 23  Basistilskudd personell og kompetanse  2021       3
# 24                     Forvaltningsmidler  2021       -
# 25              Tilskudd H.U. Sverdrup II  2021   200.1
# 26       Tilskudd Kjemiidentifikasjonslab  2021    88.8
# 27                       CBRNE-satsningen  2021      85
# 28               Tilskudd og overføringer  2021   341.8
# 29                 Strategiske FoU-midler  2021    2159
# 30    Konsept- og forprosjekteringsmidler  2021   635.1
# 31                       Forsvarssektoren  2021    5180
# 32   Sivile og offentlige, inn- og utland  2021   761.4

# %%
income.melt(id_vars=["category"], var_name="year", value_name="income")
# Out:
#                                  category  year  income
# 0                           Basistilskudd  2019     216
# 1   Basistilskudd personell og kompetanse  2019       -
# 2                      Forvaltningsmidler  2019   307.7
# 3               Tilskudd H.U. Sverdrup II  2019   284.3
# 4        Tilskudd Kjemiidentifikasjonslab  2019   107.1
# 5                        CBRNE-satsningen  2019       -
# 6                Tilskudd og overføringer  2019   389.4
# 7                  Strategiske FoU-midler  2019  2131.1
# 8     Konsept- og forprosjekteringsmidler  2019   838.2
# 9                        Forsvarssektoren  2019    3759
# 10   Sivile og offentlige, inn- og utland  2019   678.1
# 11                          Basistilskudd  2020     203
# 12  Basistilskudd personell og kompetanse  2020       -
# 13                     Forvaltningsmidler  2020   196.9
# 14              Tilskudd H.U. Sverdrup II  2020   274.2
# 15       Tilskudd Kjemiidentifikasjonslab  2020    55.7
# 16                       CBRNE-satsningen  2020       -
# 17               Tilskudd og overføringer  2020   439.1
# 18                 Strategiske FoU-midler  2020    2109
# 19    Konsept- og forprosjekteringsmidler  2020   696.2
# 20                       Forsvarssektoren  2020    3988
# 21   Sivile og offentlige, inn- og utland  2020   979.6
# 22                          Basistilskudd  2021     202
# 23  Basistilskudd personell og kompetanse  2021       3
# 24                     Forvaltningsmidler  2021       -
# 25              Tilskudd H.U. Sverdrup II  2021   200.1
# 26       Tilskudd Kjemiidentifikasjonslab  2021    88.8
# 27                       CBRNE-satsningen  2021      85
# 28               Tilskudd og overføringer  2021   341.8
# 29                 Strategiske FoU-midler  2021    2159
# 30    Konsept- og forprosjekteringsmidler  2021   635.1
# 31                       Forsvarssektoren  2021    5180
# 32   Sivile og offentlige, inn- og utland  2021   761.4

# %%
income = (
    pd.read_excel("../data/driftsinntekter-2021.xlsx", header=1)
    .rename(columns={"Category": "category"})
    .melt(id_vars=["category"], var_name="year", value_name="income")
)

# %% [markdown]
# ### Visualizations

# %%
income.plot()
# Out:
# <AxesSubplot: >

# %%
budget.plot()
# Out:
# <AxesSubplot: xlabel=' '>

# %%
budget.plot.barh()
# Out:
# <AxesSubplot: ylabel=' '>

# %% [markdown]
# ### Exercise
#
# Tidy the following data frame:

# %%
schedule = pd.DataFrame(
    {
        "hour": [19, 20, 21, 22],
        "NRK1": ["Dagsrevyen", "Beat for beat", "Nytt på nytt", "Lindmo"],
        "TV2": ["Kjære landsmenn", "Forræder", "21-nyhetene", "Farfar"],
        "TVNorge": [
            "The Big Bang Theory",
            "Alltid beredt",
            "Kongen befaler",
            "Praktisk info",
        ],
    }
)
schedule
# Out:
#    hour           NRK1              TV2              TVNorge
# 0    19     Dagsrevyen  Kjære landsmenn  The Big Bang Theory
# 1    20  Beat for beat         Forræder        Alltid beredt
# 2    21   Nytt på nytt      21-nyhetene       Kongen befaler
# 3    22         Lindmo           Farfar        Praktisk info

# %%
schedule.melt(id_vars=["hour"], var_name="channel", value_name="program")
# Out:
#     hour  channel              program
# 0     19     NRK1           Dagsrevyen
# 1     20     NRK1        Beat for beat
# 2     21     NRK1         Nytt på nytt
# 3     22     NRK1               Lindmo
# 4     19      TV2      Kjære landsmenn
# 5     20      TV2             Forræder
# 6     21      TV2          21-nyhetene
# 7     22      TV2               Farfar
# 8     19  TVNorge  The Big Bang Theory
# 9     20  TVNorge        Alltid beredt
# 10    21  TVNorge       Kongen befaler
# 11    22  TVNorge        Praktisk info

# %% [markdown]
# ## Process Data

# %% [markdown]
# ### Handle missing values

# %%
income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   category  33 non-null     object
#  1   year      33 non-null     object
#  2   income    33 non-null     object
# dtypes: object(3)
# memory usage: 920.0+ bytes

# %%
(
    pd.read_excel("../data/driftsinntekter-2021.xlsx", header=1)
    .rename(columns={"Category": "category"})
    .melt(id_vars=["category"], var_name="year", value_name="income")
    .astype({"year": "int"})
).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   category  33 non-null     object
#  1   year      33 non-null     int64
#  2   income    33 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 920.0+ bytes

# %%
(
    pd.read_excel("../data/driftsinntekter-2021.xlsx", header=1)
    .rename(columns={"Category": "category"})
    .melt(id_vars=["category"], var_name="year", value_name="income")
    .astype({"year": "int", "income": "float"})
).info()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [37], line 5
#       1 (
#       2     pd.read_excel("../data/driftsinntekter-2021.xlsx", header=1)
#       3     .rename(columns={"Category": "category"})
#       4     .melt(id_vars=["category"], var_name="year", value_name="income")
# ----> 5     .astype({"year": "int", "income": "float"})
#       6 ).info()
#
# File ~/.pyenv/versions/3.10.7/envs/kurs_ffi/lib/python3.10/site-packages/pandas/core/generic.py:6231, in NDFrame.astype(self, dtype, copy, errors)
#    6229             res_col = col.copy() if copy else col
#    6230         else:
# -> 6231             res_col = col.astype(dtype=cdt, copy=copy, errors=errors)
#    6232         results.append(res_col)
#    6234 elif is_extension_array_dtype(dtype) and self.ndim > 1:
#    6235     # GH 18099/22869: columnwise conversion to extension dtype
#    6236     # GH 24704: use iloc to handle duplicate column names
#    6237     # TODO(EA2D): special case not needed with 2D EAs
#
# File ~/.pyenv/versions/3.10.7/envs/kurs_ffi/lib/python3.10/site-packages/pandas/core/generic.py:6245, in NDFrame.astype(self, dtype, copy, errors)
#    6238     results = [
#    6239         self.iloc[:, i].astype(dtype, copy=copy)
#    6240         for i in range(len(self.columns))
#    6241     ]
#    6243 else:
#    6244     # else, only a single dtype is given
# -> 6245     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6246     return self._constructor(new_data).__finalize__(self, method="astype")
#    6248 # GH 33113: handle empty frame or series
#
# File ~/.pyenv/versions/3.10.7/envs/kurs_ffi/lib/python3.10/site-packages/pandas/core/internals/managers.py:446, in BaseBlockManager.astype(self, dtype, copy, errors)
#     445 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 446     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File ~/.pyenv/versions/3.10.7/envs/kurs_ffi/lib/python3.10/site-packages/pandas/core/internals/managers.py:348, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     346         applied = b.apply(f, **kwargs)
#     347     else:
# --> 348         applied = getattr(b, f)(**kwargs)
#     349 except (TypeError, NotImplementedError):
#     350     if not ignore_failures:
#
# File ~/.pyenv/versions/3.10.7/envs/kurs_ffi/lib/python3.10/site-packages/pandas/core/internals/blocks.py:527, in Block.astype(self, dtype, copy, errors)
#     509 """
#     510 Coerce to the new dtype.
#     511
#    (...)
#     523 Block
#     524 """
#     525 values = self.values
# --> 527 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     529 new_values = maybe_coerce_values(new_values)
#     530 newb = self.make_block(new_values)
#
# File ~/.pyenv/versions/3.10.7/envs/kurs_ffi/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:299, in astype_array_safe(values, dtype, copy, errors)
#     296     return values.copy()
#     298 try:
# --> 299     new_values = astype_array(values, dtype, copy=copy)
#     300 except (ValueError, TypeError):
#     301     # e.g. astype_nansafe can fail on object-dtype of strings
#     302     #  trying to convert to float
#     303     if errors == "ignore":
#
# File ~/.pyenv/versions/3.10.7/envs/kurs_ffi/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:230, in astype_array(values, dtype, copy)
#     227     values = values.astype(dtype, copy=copy)
#     229 else:
# --> 230     values = astype_nansafe(values, dtype, copy=copy)
#     232 # in pandas we don't store numpy str dtypes, so convert to object
#     233 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~/.pyenv/versions/3.10.7/envs/kurs_ffi/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:170, in astype_nansafe(arr, dtype, copy, skipna)
#     166     raise ValueError(msg)
#     168 if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#     169     # Explicit copy, or required since NumPy can't view from / to object.
# --> 170     return arr.astype(dtype, copy=True)
#     172 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: '-'

# %%
(
    pd.read_excel("../data/driftsinntekter-2021.xlsx", header=1, na_values="-")
    .rename(columns={"Category": "category"})
    .melt(id_vars=["category"], var_name="year", value_name="income")
    .astype({"year": "int", "income": "float"})
).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   category  33 non-null     object
#  1   year      33 non-null     int64
#  2   income    28 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 920.0+ bytes

# %%
income = (
    pd.read_excel("../data/driftsinntekter-2021.xlsx", header=1, na_values="-")
    .rename(columns={"Category": "category"})
    .melt(id_vars=["category"], var_name="year", value_name="income")
    .astype({"year": "int", "income": "float"})
)

# %%
income.dropna()
# Out:
#                                  category  year  income
# 0                           Basistilskudd  2019   216.0
# 2                      Forvaltningsmidler  2019   307.7
# 3               Tilskudd H.U. Sverdrup II  2019   284.3
# 4        Tilskudd Kjemiidentifikasjonslab  2019   107.1
# 6                Tilskudd og overføringer  2019   389.4
# 7                  Strategiske FoU-midler  2019  2131.1
# 8     Konsept- og forprosjekteringsmidler  2019   838.2
# 9                        Forsvarssektoren  2019  3759.0
# 10   Sivile og offentlige, inn- og utland  2019   678.1
# 11                          Basistilskudd  2020   203.0
# 13                     Forvaltningsmidler  2020   196.9
# 14              Tilskudd H.U. Sverdrup II  2020   274.2
# 15       Tilskudd Kjemiidentifikasjonslab  2020    55.7
# 17               Tilskudd og overføringer  2020   439.1
# 18                 Strategiske FoU-midler  2020  2109.0
# 19    Konsept- og forprosjekteringsmidler  2020   696.2
# 20                       Forsvarssektoren  2020  3988.0
# 21   Sivile og offentlige, inn- og utland  2020   979.6
# 22                          Basistilskudd  2021   202.0
# 23  Basistilskudd personell og kompetanse  2021     3.0
# 25              Tilskudd H.U. Sverdrup II  2021   200.1
# 26       Tilskudd Kjemiidentifikasjonslab  2021    88.8
# 27                       CBRNE-satsningen  2021    85.0
# 28               Tilskudd og overføringer  2021   341.8
# 29                 Strategiske FoU-midler  2021  2159.0
# 30    Konsept- og forprosjekteringsmidler  2021   635.1
# 31                       Forsvarssektoren  2021  5180.0
# 32   Sivile og offentlige, inn- og utland  2021   761.4

# %%
income.fillna(0)
# Out:
#                                  category  year  income
# 0                           Basistilskudd  2019   216.0
# 1   Basistilskudd personell og kompetanse  2019     0.0
# 2                      Forvaltningsmidler  2019   307.7
# 3               Tilskudd H.U. Sverdrup II  2019   284.3
# 4        Tilskudd Kjemiidentifikasjonslab  2019   107.1
# 5                        CBRNE-satsningen  2019     0.0
# 6                Tilskudd og overføringer  2019   389.4
# 7                  Strategiske FoU-midler  2019  2131.1
# 8     Konsept- og forprosjekteringsmidler  2019   838.2
# 9                        Forsvarssektoren  2019  3759.0
# 10   Sivile og offentlige, inn- og utland  2019   678.1
# 11                          Basistilskudd  2020   203.0
# 12  Basistilskudd personell og kompetanse  2020     0.0
# 13                     Forvaltningsmidler  2020   196.9
# 14              Tilskudd H.U. Sverdrup II  2020   274.2
# 15       Tilskudd Kjemiidentifikasjonslab  2020    55.7
# 16                       CBRNE-satsningen  2020     0.0
# 17               Tilskudd og overføringer  2020   439.1
# 18                 Strategiske FoU-midler  2020  2109.0
# 19    Konsept- og forprosjekteringsmidler  2020   696.2
# 20                       Forsvarssektoren  2020  3988.0
# 21   Sivile og offentlige, inn- og utland  2020   979.6
# 22                          Basistilskudd  2021   202.0
# 23  Basistilskudd personell og kompetanse  2021     3.0
# 24                     Forvaltningsmidler  2021     0.0
# 25              Tilskudd H.U. Sverdrup II  2021   200.1
# 26       Tilskudd Kjemiidentifikasjonslab  2021    88.8
# 27                       CBRNE-satsningen  2021    85.0
# 28               Tilskudd og overføringer  2021   341.8
# 29                 Strategiske FoU-midler  2021  2159.0
# 30    Konsept- og forprosjekteringsmidler  2021   635.1
# 31                       Forsvarssektoren  2021  5180.0
# 32   Sivile og offentlige, inn- og utland  2021   761.4

# %% [markdown]
# ### Select variables and observations

# %%
budget = (
    pd.read_excel(
        "../data/kap1.xlsx", sheet_name="1.2", header=4, index_col=0, na_values="-"
    )
    .rename(columns={"Budsjettiltak": "tiltak", "Lån og garantier": "lån"})
    .fillna(0)
)

# %%
budget
# Out:
#                tiltak   lån
#
# India             0.7   0.0
# Frankrike         0.7  13.9
# Russland          0.9   0.6
# Spania            1.2   9.8
# Italia            1.2  32.4
# Korea             1.5   6.4
# Finland           1.7   5.4
# Kina              2.5   0.0
# Nederland         2.7   0.0
# Brasil            2.9   4.2
# Storbritannia     3.1  15.7
# Sverige           3.4   5.0
# Tyskland          4.4  29.6
# Danmark           4.9   5.3
# Norge             5.1   4.0
# Canada            5.2   3.3
# USA               6.9   4.2
# Japan            10.0  10.4
# Australia        10.6   1.9

# %%
budget.tiltak
# Out:
#
# India             0.7
# Frankrike         0.7
# Russland          0.9
# Spania            1.2
# Italia            1.2
# Korea             1.5
# Finland           1.7
# Kina              2.5
# Nederland         2.7
# Brasil            2.9
# Storbritannia     3.1
# Sverige           3.4
# Tyskland          4.4
# Danmark           4.9
# Norge             5.1
# Canada            5.2
# USA               6.9
# Japan            10.0
# Australia        10.6
# Name: tiltak, dtype: float64

# %%
budget["tiltak"]
# Out:
#
# India             0.7
# Frankrike         0.7
# Russland          0.9
# Spania            1.2
# Italia            1.2
# Korea             1.5
# Finland           1.7
# Kina              2.5
# Nederland         2.7
# Brasil            2.9
# Storbritannia     3.1
# Sverige           3.4
# Tyskland          4.4
# Danmark           4.9
# Norge             5.1
# Canada            5.2
# USA               6.9
# Japan            10.0
# Australia        10.6
# Name: tiltak, dtype: float64

# %%
budget.loc[:, "tiltak"]
# Out:
#
# India             0.7
# Frankrike         0.7
# Russland          0.9
# Spania            1.2
# Italia            1.2
# Korea             1.5
# Finland           1.7
# Kina              2.5
# Nederland         2.7
# Brasil            2.9
# Storbritannia     3.1
# Sverige           3.4
# Tyskland          4.4
# Danmark           4.9
# Norge             5.1
# Canada            5.2
# USA               6.9
# Japan            10.0
# Australia        10.6
# Name: tiltak, dtype: float64

# %%
budget.loc["Norge"]
# Out:
# tiltak    5.1
# lån       4.0
# Name: Norge, dtype: float64

# %%
budget.loc["Sverige":"Norge"]
# Out:
#           tiltak   lån
#
# Sverige      3.4   5.0
# Tyskland     4.4  29.6
# Danmark      4.9   5.3
# Norge        5.1   4.0

# %%
budget.loc[["Norge", "Sverige", "Danmark", "Finland"]]
# Out:
#          tiltak  lån
#
# Norge       5.1  4.0
# Sverige     3.4  5.0
# Danmark     4.9  5.3
# Finland     1.7  5.4

# %%
budget.loc[["Norge", "Sverige", "Danmark", "Finland"], "lån"]
# Out:
#
# Norge      4.0
# Sverige    5.0
# Danmark    5.3
# Finland    5.4
# Name: lån, dtype: float64

# %%
budget.loc[["Norge", "Sverige", "Danmark", "Finland"], ["lån", "tiltak"]]
# Out:
#          lån  tiltak
#
# Norge    4.0     5.1
# Sverige  5.0     3.4
# Danmark  5.3     4.9
# Finland  5.4     1.7

# %%
budget.iloc[4]
# Out:
# tiltak     1.2
# lån       32.4
# Name: Italia, dtype: float64

# %%
budget.iloc[4:9]
# Out:
#            tiltak   lån
#
# Italia        1.2  32.4
# Korea         1.5   6.4
# Finland       1.7   5.4
# Kina          2.5   0.0
# Nederland     2.7   0.0

# %%
budget.iloc[5:8, 0]
# Out:
#
# Korea      1.5
# Finland    1.7
# Kina       2.5
# Name: tiltak, dtype: float64

# %%
budget.loc["Norge", "tiltak"]
# Out:
# 5.1

# %%
budget.loc["Norge", budget.columns[1]]
# Out:
# 4.0

# %% [markdown]
# ### Combine variables

# %%
budget.tiltak + budget.lån
# Out:
#
# India             0.7
# Frankrike        14.6
# Russland          1.5
# Spania           11.0
# Italia           33.6
# Korea             7.9
# Finland           7.1
# Kina              2.5
# Nederland         2.7
# Brasil            7.1
# Storbritannia    18.8
# Sverige           8.4
# Tyskland         34.0
# Danmark          10.2
# Norge             9.1
# Canada            8.5
# USA              11.1
# Japan            20.4
# Australia        12.5
# dtype: float64

# %%
budget.assign(total=budget.tiltak + budget.lån)
# Out:
#                tiltak   lån  total
#
# India             0.7   0.0    0.7
# Frankrike         0.7  13.9   14.6
# Russland          0.9   0.6    1.5
# Spania            1.2   9.8   11.0
# Italia            1.2  32.4   33.6
# Korea             1.5   6.4    7.9
# Finland           1.7   5.4    7.1
# Kina              2.5   0.0    2.5
# Nederland         2.7   0.0    2.7
# Brasil            2.9   4.2    7.1
# Storbritannia     3.1  15.7   18.8
# Sverige           3.4   5.0    8.4
# Tyskland          4.4  29.6   34.0
# Danmark           4.9   5.3   10.2
# Norge             5.1   4.0    9.1
# Canada            5.2   3.3    8.5
# USA               6.9   4.2   11.1
# Japan            10.0  10.4   20.4
# Australia        10.6   1.9   12.5

# %% [markdown]
# ### Filter observations

# %%
budget.query("tiltak > 6")
# Out:
#            tiltak   lån
#
# USA           6.9   4.2
# Japan        10.0  10.4
# Australia    10.6   1.9

# %%
budget.query("lån < 3")
# Out:
#            tiltak  lån
#
# India         0.7  0.0
# Russland      0.9  0.6
# Kina          2.5  0.0
# Nederland     2.7  0.0
# Australia    10.6  1.9

# %%
budget.query("tiltak >= lån")
# Out:
#            tiltak  lån
#
# India         0.7  0.0
# Russland      0.9  0.6
# Kina          2.5  0.0
# Nederland     2.7  0.0
# Norge         5.1  4.0
# Canada        5.2  3.3
# USA           6.9  4.2
# Australia    10.6  1.9

# %% [markdown]
# ### Sort observations

# %%
budget.sort_values(by="lån")
# Out:
#                tiltak   lån
#
# India             0.7   0.0
# Nederland         2.7   0.0
# Kina              2.5   0.0
# Russland          0.9   0.6
# Australia        10.6   1.9
# Canada            5.2   3.3
# Norge             5.1   4.0
# USA               6.9   4.2
# Brasil            2.9   4.2
# Sverige           3.4   5.0
# Danmark           4.9   5.3
# Finland           1.7   5.4
# Korea             1.5   6.4
# Spania            1.2   9.8
# Japan            10.0  10.4
# Frankrike         0.7  13.9
# Storbritannia     3.1  15.7
# Tyskland          4.4  29.6
# Italia            1.2  32.4

# %%
budget.sort_values(by=["lån", "tiltak"])
# Out:
#                tiltak   lån
#
# India             0.7   0.0
# Kina              2.5   0.0
# Nederland         2.7   0.0
# Russland          0.9   0.6
# Australia        10.6   1.9
# Canada            5.2   3.3
# Norge             5.1   4.0
# Brasil            2.9   4.2
# USA               6.9   4.2
# Sverige           3.4   5.0
# Danmark           4.9   5.3
# Finland           1.7   5.4
# Korea             1.5   6.4
# Spania            1.2   9.8
# Japan            10.0  10.4
# Frankrike         0.7  13.9
# Storbritannia     3.1  15.7
# Tyskland          4.4  29.6
# Italia            1.2  32.4

# %%
budget.sort_index()
# Out:
#                tiltak   lån
#
# Australia        10.6   1.9
# Brasil            2.9   4.2
# Canada            5.2   3.3
# Danmark           4.9   5.3
# Finland           1.7   5.4
# Frankrike         0.7  13.9
# India             0.7   0.0
# Italia            1.2  32.4
# Japan            10.0  10.4
# Kina              2.5   0.0
# Korea             1.5   6.4
# Nederland         2.7   0.0
# Norge             5.1   4.0
# Russland          0.9   0.6
# Spania            1.2   9.8
# Storbritannia     3.1  15.7
# Sverige           3.4   5.0
# Tyskland          4.4  29.6
# USA               6.9   4.2

# %% [markdown]
# ### Exercise
#
# Something something driftsinntekter

# %% [markdown]
# ## Aggregate Data

# %% [markdown]
# ### Bigger datasets

# %%
pd.read_csv("../data/09.csv")
# Out:
#                               started_at                          ended_at  \
# 0       2022-09-01 03:04:31.178000+00:00  2022-09-01 03:13:01.298000+00:00
# 1       2022-09-01 03:11:09.104000+00:00  2022-09-01 03:14:52.506000+00:00
# 2       2022-09-01 03:11:37.861000+00:00  2022-09-01 03:23:23.939000+00:00
# 3       2022-09-01 03:13:00.843000+00:00  2022-09-01 03:17:17.639000+00:00
# 4       2022-09-01 03:13:13.330000+00:00  2022-09-01 03:24:15.758000+00:00
# ...                                  ...                               ...
# 165872  2022-09-30 22:58:48.433000+00:00  2022-09-30 23:36:10.742000+00:00
# 165873  2022-09-30 22:59:04.940000+00:00  2022-09-30 23:10:24.031000+00:00
# 165874  2022-09-30 22:59:20.017000+00:00  2022-09-30 23:03:35.663000+00:00
# 165875  2022-09-30 22:59:41.280000+00:00  2022-09-30 23:07:23.601000+00:00
# 165876  2022-09-30 23:46:23.621000+00:00  2022-09-30 23:49:41.181000+00:00
#
#         duration  start_station_id         start_station_name  \
# 0            510               437              Sentrum Scene
# 1            223               578              Hallings gate
# 2            706               421  Alexander Kiellands Plass
# 3            256               735              Oslo Hospital
# 4            662               525              Myraløkka Øst
# ...          ...               ...                        ...
# 165872      2242               430           Spikersuppa Vest
# 165873       679               558                  Dokkveien
# 165874       255               424                Birkelunden
# 165875       462               421  Alexander Kiellands Plass
# 165876       197               428          Olav Kyrres plass
#
#            start_station_description  start_station_latitude  \
# 0       ved Arbeidersamfunnets plass               59.915468
# 1                langs Dalsbergstien               59.922777
# 2                langs Maridalsveien               59.928067
# 3                  ved trikkestoppet               59.903213
# 4                    ved Bentsenbrua               59.937205
# ...                              ...                     ...
# 165872          ved Nasjonalteateret               59.913720
# 165873               ved Støperigata               59.910974
# 165874            langs Seilduksgata               59.925611
# 165875           langs Maridalsveien               59.928067
# 165876  ved den sveitsiske ambassade               59.919334
#
#         start_station_longitude  end_station_id      end_station_name  \
# 0                     10.751141             583             Galgeberg
# 1                     10.738655             499     Bjerregaards gate
# 2                     10.751203             390             Saga Kino
# 3                     10.767344             465              Bjørvika
# 4                     10.760581             443  Sjøsiden ved trappen
# ...                         ...             ...                   ...
# 165872                10.735887             479            Tjuvholmen
# 165873                10.727700             597           Fredensborg
# 165874                10.760926             744          Hallénparken
# 165875                10.751203             469    Studentparlamentet
# 165876                10.696895             429                 Thune
#
#              end_station_description  end_station_latitude  \
# 0            langs St. Halvards gate             59.907076
# 1       ovenfor Fredrikke Qvams gate             59.925488
# 2                 langs Olav Vs gate             59.914240
# 3           under broen Nylandsveien             59.909006
# 4                             Oslo S             59.910154
# ...                              ...                   ...
# 165872              ved Bryggegangen             59.909467
# 165873             ved rundkjøringen             59.920995
# 165874                ved Vogts gate             59.931530
# 165875     ved Frydenlund holdeplass             59.920852
# 165876                 ved bomringen             59.922080
#
#         end_station_longitude
# 0                   10.779164
# 1                   10.746058
# 2                   10.732771
# 3                   10.756180
# 4                   10.751981
# ...                       ...
# 165872              10.722509
# 165873              10.750358
# 165874              10.762169
# 165875              10.733357
# 165876              10.685880
#
# [165877 rows x 13 columns]

# %%
trips = pd.read_csv("../data/09.csv")

# %%
trips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165877 entries, 0 to 165876
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   started_at                 165877 non-null  object
#  1   ended_at                   165877 non-null  object
#  2   duration                   165877 non-null  int64
#  3   start_station_id           165877 non-null  int64
#  4   start_station_name         165877 non-null  object
#  5   start_station_description  165876 non-null  object
#  6   start_station_latitude     165877 non-null  float64
#  7   start_station_longitude    165877 non-null  float64
#  8   end_station_id             165877 non-null  int64
#  9   end_station_name           165877 non-null  object
#  10  end_station_description    165876 non-null  object
#  11  end_station_latitude       165877 non-null  float64
#  12  end_station_longitude      165877 non-null  float64
# dtypes: float64(4), int64(3), object(6)
# memory usage: 16.5+ MB

# %% [markdown]
# ### Date columns

# %%
trips = pd.read_csv("../data/09.csv", parse_dates=["started_at", "ended_at"])
trips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165877 entries, 0 to 165876
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   started_at                 165877 non-null  datetime64[ns, UTC]
#  1   ended_at                   165877 non-null  datetime64[ns, UTC]
#  2   duration                   165877 non-null  int64
#  3   start_station_id           165877 non-null  int64
#  4   start_station_name         165877 non-null  object
#  5   start_station_description  165876 non-null  object
#  6   start_station_latitude     165877 non-null  float64
#  7   start_station_longitude    165877 non-null  float64
#  8   end_station_id             165877 non-null  int64
#  9   end_station_name           165877 non-null  object
#  10  end_station_description    165876 non-null  object
#  11  end_station_latitude       165877 non-null  float64
#  12  end_station_longitude      165877 non-null  float64
# dtypes: datetime64[ns, UTC](2), float64(4), int64(3), object(4)
# memory usage: 16.5+ MB

# %% [markdown]
# ### Group by common values

# %%
trips.groupby("start_station_name")

# %%
trips.groupby("start_station_name").size()
# Out:
# start_station_name
# 7. juni-plassen           959
# AHO                      1547
# Adamstuen                 316
# Aker Brygge              2079
# Akerselvallmenningen      661
#                          ...
# Vulkan                   1216
# Vålerenga                 245
# Vår Frelsers gravlund    1442
# Økern Portal              144
# Økernveien                 86
# Length: 263, dtype: int64

# %%
trips.groupby("start_station_name").size().sort_values()
# Out:
# start_station_name
# Tordenskiolds gate             44
# Gaustad T-bane                 58
# Furulund                       72
# Kværnerveien                   74
# Grenseveien                    84
#                              ...
# Olaf Ryes plass              1918
# Ringnes Park                 1970
# Helga Helgesens plass        1984
# Aker Brygge                  2079
# Alexander Kiellands Plass    2133
# Length: 263, dtype: int64

# %%
trips.groupby("start_station_name").size().reset_index()
# Out:
#         start_station_name     0
# 0          7. juni-plassen   959
# 1                      AHO  1547
# 2                Adamstuen   316
# 3              Aker Brygge  2079
# 4     Akerselvallmenningen   661
# ..                     ...   ...
# 258                 Vulkan  1216
# 259              Vålerenga   245
# 260  Vår Frelsers gravlund  1442
# 261           Økern Portal   144
# 262             Økernveien    86
#
# [263 rows x 2 columns]

# %%
(
    trips.groupby("start_station_name")
    .size()
    .reset_index()
    .rename(columns={0: "num_trips"})
)
# Out:
#         start_station_name  num_trips
# 0          7. juni-plassen        959
# 1                      AHO       1547
# 2                Adamstuen        316
# 3              Aker Brygge       2079
# 4     Akerselvallmenningen        661
# ..                     ...        ...
# 258                 Vulkan       1216
# 259              Vålerenga        245
# 260  Vår Frelsers gravlund       1442
# 261           Økern Portal        144
# 262             Økernveien         86
#
# [263 rows x 2 columns]

# %%
(
    trips.groupby("start_station_name")
    .size()
    .reset_index()
    .rename(columns={0: "num_trips"})
    .sort_values(by="num_trips")
)
# Out:
#             start_station_name  num_trips
# 233         Tordenskiolds gate         44
# 78              Gaustad T-bane         58
# 74                    Furulund         72
# 127               Kværnerveien         74
# 81                 Grenseveien         84
# ..                         ...        ...
# 160            Olaf Ryes plass       1918
# 175               Ringnes Park       1970
# 96       Helga Helgesens plass       1984
# 3                  Aker Brygge       2079
# 6    Alexander Kiellands Plass       2133
#
# [263 rows x 2 columns]

# %%
(
    trips.groupby("end_station_name")
    .size()
    .reset_index()
    .rename(columns={0: "num_trips"})
    .sort_values(by="num_trips")
)
# Out:
#           end_station_name  num_trips
# 78          Gaustad T-bane         22
# 176    Rolf Wickstrøms vei         44
# 127           Kværnerveien         60
# 33             Borgenveien         60
# 92              HasleLinje         61
# ..                     ...        ...
# 192   Sjøsiden ved trappen       2264
# 234               Torggata       2266
# 119            Kirkeristen       2318
# 96   Helga Helgesens plass       2414
# 3              Aker Brygge       3446
#
# [263 rows x 2 columns]

# %%
num_trips = (
    trips.groupby("start_station_name")
    .size()
    .reset_index()
    .rename(columns={0: "num_trips"})
    .sort_values(by="num_trips")
)

# %% [markdown]
# ### Aggregations: sum, mean, median, first, count, ...

# %%
trips.groupby("start_station_name").median()
# Out:
# /tmp/ipykernel_1050153/1814469195.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   trips.groupby("start_station_name").median()
#                        duration  start_station_id  start_station_latitude  \
# start_station_name
# 7. juni-plassen           423.0             623.0               59.915060
# AHO                       482.0             444.0               59.925265
# Adamstuen                 521.5             425.0               59.932792
# Aker Brygge               625.0            1755.0               59.911184
# Akerselvallmenningen      738.0            2333.0               59.907259
# ...                         ...               ...                     ...
# Vulkan                    472.0             442.0               59.922510
# Vålerenga                 503.0             461.0               59.908576
# Vår Frelsers gravlund     420.0             384.0               59.919440
# Økern Portal              858.0            2306.0               59.930904
# Økernveien                432.0             605.0               59.916738
#
#                        start_station_longitude  end_station_id  \
# start_station_name
# 7. juni-plassen                      10.731272           484.0
# AHO                                  10.750462           500.0
# Adamstuen                            10.734457           489.0
# Aker Brygge                          10.730035           503.0
# Akerselvallmenningen                 10.754885           489.0
# ...                                        ...             ...
# Vulkan                               10.751010           490.0
# Vålerenga                            10.786856           507.0
# Vår Frelsers gravlund                10.743765           491.0
# Økern Portal                         10.801940           513.0
# Økernveien                           10.779916           491.0
#
#                        end_station_latitude  end_station_longitude
# start_station_name
# 7. juni-plassen                   59.918578              10.732839
# AHO                               59.915418              10.750910
# Adamstuen                         59.923829              10.738629
# Aker Brygge                       59.914240              10.746761
# Akerselvallmenningen              59.913575              10.750910
# ...                                     ...                    ...
# Vulkan                            59.914943              10.750110
# Vålerenga                         59.911784              10.761000
# Vår Frelsers gravlund             59.915468              10.749202
# Økern Portal                      59.921206              10.766182
# Økernveien                        59.920532              10.761994
#
# [263 rows x 7 columns]

# %%
trips.groupby("start_station_name").agg(median_duration=("duration", "median"))
# Out:
#                        median_duration
# start_station_name
# 7. juni-plassen                  423.0
# AHO                              482.0
# Adamstuen                        521.5
# Aker Brygge                      625.0
# Akerselvallmenningen             738.0
# ...                                ...
# Vulkan                           472.0
# Vålerenga                        503.0
# Vår Frelsers gravlund            420.0
# Økern Portal                     858.0
# Økernveien                       432.0
#
# [263 rows x 1 columns]

# %%
# Sidenote, we could do the size example as follows
trips.groupby("start_station_name").agg(
    num_trips=("start_station_name", "size")
).reset_index().sort_values(by="num_trips")
# Out:
#             start_station_name  num_trips
# 233         Tordenskiolds gate         44
# 78              Gaustad T-bane         58
# 74                    Furulund         72
# 127               Kværnerveien         74
# 81                 Grenseveien         84
# ..                         ...        ...
# 160            Olaf Ryes plass       1918
# 175               Ringnes Park       1970
# 96       Helga Helgesens plass       1984
# 3                  Aker Brygge       2079
# 6    Alexander Kiellands Plass       2133
#
# [263 rows x 2 columns]

# %%
trips.groupby("start_station_name").agg(
    median_duration=("duration", "median"),
    description=("start_station_description", "first"),
)
# Out:
#                        median_duration                    description
# start_station_name
# 7. juni-plassen                  423.0       langs Henrik Ibsens gate
# AHO                              482.0            langs Maridalsveien
# Adamstuen                        521.5              ved trikkestoppen
# Aker Brygge                      625.0                ved trikkestopp
# Akerselvallmenningen             738.0                øst for Operaen
# ...                                ...                            ...
# Vulkan                           472.0              ved Maridalsveien
# Vålerenga                        503.0           langs Ingeborgs gate
# Vår Frelsers gravlund            420.0            langs Ullevålsveien
# Økern Portal                     858.0      ved Dag Hammarskjölds vei
# Økernveien                       432.0  ved Ensjøveien bussholdeplass
#
# [263 rows x 2 columns]

# %%
def most_common(column):
    return column.mode().iloc[0]


trips.groupby("start_station_name").agg(
    median_duration=("duration", "median"),
    description=("start_station_description", "first"),
    common_end_station=("end_station_name", most_common),
)
# Out:
#                        median_duration                    description  \
# start_station_name
# 7. juni-plassen                  423.0       langs Henrik Ibsens gate
# AHO                              482.0            langs Maridalsveien
# Adamstuen                        521.5              ved trikkestoppen
# Aker Brygge                      625.0                ved trikkestopp
# Akerselvallmenningen             738.0                øst for Operaen
# ...                                ...                            ...
# Vulkan                           472.0              ved Maridalsveien
# Vålerenga                        503.0           langs Ingeborgs gate
# Vår Frelsers gravlund            420.0            langs Ullevålsveien
# Økern Portal                     858.0      ved Dag Hammarskjölds vei
# Økernveien                       432.0  ved Ensjøveien bussholdeplass
#
#                           common_end_station
# start_station_name
# 7. juni-plassen                      OsloMet
# AHO                    Helga Helgesens plass
# Adamstuen              Vår Frelsers gravlund
# Aker Brygge                        Saga Kino
# Akerselvallmenningen             Aker Brygge
# ...                                      ...
# Vulkan                                Vulkan
# Vålerenga              Helga Helgesens plass
# Vår Frelsers gravlund              Akersgata
# Økern Portal                       Munkegata
# Økernveien                 Botanisk Hage sør
#
# [263 rows x 3 columns]

# %%
trips.groupby(["start_station_name", "end_station_name"]).agg(
    median_duration=("duration", "median")
)
# Out:
#                                          median_duration
# start_station_name end_station_name
# 7. juni-plassen    7. juni-plassen                 101.0
#                    AHO                             728.0
#                    Adamstuen                       711.0
#                    Aker Brygge                     281.0
#                    Akerselvallmenningen            587.0
# ...                                                  ...
# Økernveien         Tøyen skole                     145.5
#                    Tøyenbekken                     308.0
#                    Tøyenparken                      72.0
#                    Vulkan                          569.0
#                    Økern Portal                    668.0
#
# [35930 rows x 1 columns]

# %%
trips.groupby(["start_station_name", "end_station_name"]).agg(
    median_duration=("duration", "median"),
    start_station_description=("start_station_description", "first"),
    end_station_description=("end_station_description", "first"),
)
# Out:
#                                          median_duration  \
# start_station_name end_station_name
# 7. juni-plassen    7. juni-plassen                 101.0
#                    AHO                             728.0
#                    Adamstuen                       711.0
#                    Aker Brygge                     281.0
#                    Akerselvallmenningen            587.0
# ...                                                  ...
# Økernveien         Tøyen skole                     145.5
#                    Tøyenbekken                     308.0
#                    Tøyenparken                      72.0
#                    Vulkan                          569.0
#                    Økern Portal                    668.0
#
#                                              start_station_description  \
# start_station_name end_station_name
# 7. juni-plassen    7. juni-plassen            langs Henrik Ibsens gate
#                    AHO                        langs Henrik Ibsens gate
#                    Adamstuen                  langs Henrik Ibsens gate
#                    Aker Brygge                langs Henrik Ibsens gate
#                    Akerselvallmenningen       langs Henrik Ibsens gate
# ...                                                                ...
# Økernveien         Tøyen skole           ved Ensjøveien bussholdeplass
#                    Tøyenbekken           ved Ensjøveien bussholdeplass
#                    Tøyenparken           ved Ensjøveien bussholdeplass
#                    Vulkan                ved Ensjøveien bussholdeplass
#                    Økern Portal          ved Ensjøveien bussholdeplass
#
#                                            end_station_description
# start_station_name end_station_name
# 7. juni-plassen    7. juni-plassen        langs Henrik Ibsens gate
#                    AHO                         langs Maridalsveien
#                    Adamstuen                     ved trikkestoppen
#                    Aker Brygge                     ved trikkestopp
#                    Akerselvallmenningen            øst for Operaen
# ...                                                            ...
# Økernveien         Tøyen skole             forsiden av skolebygget
#                    Tøyenbekken               ved Rubina Ranas gate
#                    Tøyenparken                     ved Caltexløkka
#                    Vulkan                        ved Maridalsveien
#                    Økern Portal          ved Dag Hammarskjölds vei
#
# [35930 rows x 3 columns]

# %%
trips.groupby(["start_station_name", "end_station_name"]).agg(
    median_duration=("duration", "median"),
    start_station_description=("start_station_description", "first"),
    end_station_description=("end_station_description", "first"),
).reset_index()
# Out:
#       start_station_name      end_station_name  median_duration  \
# 0        7. juni-plassen       7. juni-plassen            101.0
# 1        7. juni-plassen                   AHO            728.0
# 2        7. juni-plassen             Adamstuen            711.0
# 3        7. juni-plassen           Aker Brygge            281.0
# 4        7. juni-plassen  Akerselvallmenningen            587.0
# ...                  ...                   ...              ...
# 35925         Økernveien           Tøyen skole            145.5
# 35926         Økernveien           Tøyenbekken            308.0
# 35927         Økernveien           Tøyenparken             72.0
# 35928         Økernveien                Vulkan            569.0
# 35929         Økernveien          Økern Portal            668.0
#
#            start_station_description    end_station_description
# 0           langs Henrik Ibsens gate   langs Henrik Ibsens gate
# 1           langs Henrik Ibsens gate        langs Maridalsveien
# 2           langs Henrik Ibsens gate          ved trikkestoppen
# 3           langs Henrik Ibsens gate            ved trikkestopp
# 4           langs Henrik Ibsens gate            øst for Operaen
# ...                              ...                        ...
# 35925  ved Ensjøveien bussholdeplass    forsiden av skolebygget
# 35926  ved Ensjøveien bussholdeplass      ved Rubina Ranas gate
# 35927  ved Ensjøveien bussholdeplass            ved Caltexløkka
# 35928  ved Ensjøveien bussholdeplass          ved Maridalsveien
# 35929  ved Ensjøveien bussholdeplass  ved Dag Hammarskjölds vei
#
# [35930 rows x 5 columns]

# %% [markdown]
# ### Exercise

# %% [markdown]
# ## Combine Data Tables
#
# We have two files with the same kinds of data: `08.csv` with data for August and `09.csv` with data for September. How can we combine them into one DataFrame?

# %%
data_aug = pd.read_csv("../data/08.csv", parse_dates=["started_at", "ended_at"])
data_sep = pd.read_csv("../data/09.csv", parse_dates=["started_at", "ended_at"])

# %% [markdown]
# ### Append tables with similar data

# %%
pd.concat([data_aug, data_sep])
# Out:
#                              started_at                         ended_at  \
# 0      2022-08-01 03:08:45.036000+00:00 2022-08-01 03:11:38.571000+00:00
# 1      2022-08-01 03:09:05.419000+00:00 2022-08-01 03:18:15.885000+00:00
# 2      2022-08-01 03:22:25.178000+00:00 2022-08-01 03:30:57.051000+00:00
# 3      2022-08-01 03:29:20.355000+00:00 2022-08-01 03:38:43.156000+00:00
# 4      2022-08-01 03:29:25.883000+00:00 2022-08-01 03:37:00.311000+00:00
# ...                                 ...                              ...
# 165872 2022-09-30 22:58:48.433000+00:00 2022-09-30 23:36:10.742000+00:00
# 165873 2022-09-30 22:59:04.940000+00:00 2022-09-30 23:10:24.031000+00:00
# 165874 2022-09-30 22:59:20.017000+00:00 2022-09-30 23:03:35.663000+00:00
# 165875 2022-09-30 22:59:41.280000+00:00 2022-09-30 23:07:23.601000+00:00
# 165876 2022-09-30 23:46:23.621000+00:00 2022-09-30 23:49:41.181000+00:00
#
#         duration  start_station_id         start_station_name  \
# 0            173               564                Oscars gate
# 1            550               421  Alexander Kiellands Plass
# 2            511               621           Torshovdalen øst
# 3            562               447                Kværnerbyen
# 4            454               421  Alexander Kiellands Plass
# ...          ...               ...                        ...
# 165872      2242               430           Spikersuppa Vest
# 165873       679               558                  Dokkveien
# 165874       255               424                Birkelunden
# 165875       462               421  Alexander Kiellands Plass
# 165876       197               428          Olav Kyrres plass
#
#            start_station_description  start_station_latitude  \
# 0                ved Hegdehaugsveien               59.922422
# 1                langs Maridalsveien               59.928067
# 2       ved Mailundveien rundkjøring               59.932857
# 3                langs Smeltedigelen               59.904473
# 4                langs Maridalsveien               59.928067
# ...                              ...                     ...
# 165872          ved Nasjonalteateret               59.913720
# 165873               ved Støperigata               59.910974
# 165874            langs Seilduksgata               59.925611
# 165875           langs Maridalsveien               59.928067
# 165876  ved den sveitsiske ambassade               59.919334
#
#         start_station_longitude  end_station_id    end_station_name  \
# 0                     10.727239             511  Henrik Ibsens gate
# 1                     10.751203             408         Tøyen skole
# 2                     10.777633             495    Vaterlandsparken
# 3                     10.786167             475       Hausmanns bru
# 4                     10.751203             557           Akersgata
# ...                         ...             ...                 ...
# 165872                10.735887             479          Tjuvholmen
# 165873                10.727700             597         Fredensborg
# 165874                10.760926             744        Hallénparken
# 165875                10.751203             469  Studentparlamentet
# 165876                10.696895             429               Thune
#
#           end_station_description  end_station_latitude  end_station_longitude
# 0                   ved Parkveien             59.915088              10.722280
# 1         forsiden av skolebygget             59.914943              10.773977
# 2                   langs Brugata             59.913516              10.757335
# 3              langs Nylandsveien             59.914651              10.759872
# 4                     ved Grensen             59.914197              10.742883
# ...                           ...                   ...                    ...
# 165872           ved Bryggegangen             59.909467              10.722509
# 165873          ved rundkjøringen             59.920995              10.750358
# 165874             ved Vogts gate             59.931530              10.762169
# 165875  ved Frydenlund holdeplass             59.920852              10.733357
# 165876              ved bomringen             59.922080              10.685880
#
# [373210 rows x 13 columns]

# %%
pd.concat([data_aug, data_sep]).reset_index()
# Out:
#          index                       started_at  \
# 0            0 2022-08-01 03:08:45.036000+00:00
# 1            1 2022-08-01 03:09:05.419000+00:00
# 2            2 2022-08-01 03:22:25.178000+00:00
# 3            3 2022-08-01 03:29:20.355000+00:00
# 4            4 2022-08-01 03:29:25.883000+00:00
# ...        ...                              ...
# 373205  165872 2022-09-30 22:58:48.433000+00:00
# 373206  165873 2022-09-30 22:59:04.940000+00:00
# 373207  165874 2022-09-30 22:59:20.017000+00:00
# 373208  165875 2022-09-30 22:59:41.280000+00:00
# 373209  165876 2022-09-30 23:46:23.621000+00:00
#
#                                ended_at  duration  start_station_id  \
# 0      2022-08-01 03:11:38.571000+00:00       173               564
# 1      2022-08-01 03:18:15.885000+00:00       550               421
# 2      2022-08-01 03:30:57.051000+00:00       511               621
# 3      2022-08-01 03:38:43.156000+00:00       562               447
# 4      2022-08-01 03:37:00.311000+00:00       454               421
# ...                                 ...       ...               ...
# 373205 2022-09-30 23:36:10.742000+00:00      2242               430
# 373206 2022-09-30 23:10:24.031000+00:00       679               558
# 373207 2022-09-30 23:03:35.663000+00:00       255               424
# 373208 2022-09-30 23:07:23.601000+00:00       462               421
# 373209 2022-09-30 23:49:41.181000+00:00       197               428
#
#                start_station_name     start_station_description  \
# 0                     Oscars gate           ved Hegdehaugsveien
# 1       Alexander Kiellands Plass           langs Maridalsveien
# 2                Torshovdalen øst  ved Mailundveien rundkjøring
# 3                     Kværnerbyen           langs Smeltedigelen
# 4       Alexander Kiellands Plass           langs Maridalsveien
# ...                           ...                           ...
# 373205           Spikersuppa Vest          ved Nasjonalteateret
# 373206                  Dokkveien               ved Støperigata
# 373207                Birkelunden            langs Seilduksgata
# 373208  Alexander Kiellands Plass           langs Maridalsveien
# 373209          Olav Kyrres plass  ved den sveitsiske ambassade
#
#         start_station_latitude  start_station_longitude  end_station_id  \
# 0                    59.922422                10.727239             511
# 1                    59.928067                10.751203             408
# 2                    59.932857                10.777633             495
# 3                    59.904473                10.786167             475
# 4                    59.928067                10.751203             557
# ...                        ...                      ...             ...
# 373205               59.913720                10.735887             479
# 373206               59.910974                10.727700             597
# 373207               59.925611                10.760926             744
# 373208               59.928067                10.751203             469
# 373209               59.919334                10.696895             429
#
#           end_station_name    end_station_description  end_station_latitude  \
# 0       Henrik Ibsens gate              ved Parkveien             59.915088
# 1              Tøyen skole    forsiden av skolebygget             59.914943
# 2         Vaterlandsparken              langs Brugata             59.913516
# 3            Hausmanns bru         langs Nylandsveien             59.914651
# 4                Akersgata                ved Grensen             59.914197
# ...                    ...                        ...                   ...
# 373205          Tjuvholmen           ved Bryggegangen             59.909467
# 373206         Fredensborg          ved rundkjøringen             59.920995
# 373207        Hallénparken             ved Vogts gate             59.931530
# 373208  Studentparlamentet  ved Frydenlund holdeplass             59.920852
# 373209               Thune              ved bomringen             59.922080
#
#         end_station_longitude
# 0                   10.722280
# 1                   10.773977
# 2                   10.757335
# 3                   10.759872
# 4                   10.742883
# ...                       ...
# 373205              10.722509
# 373206              10.750358
# 373207              10.762169
# 373208              10.733357
# 373209              10.685880
#
# [373210 rows x 14 columns]

# %%
pd.concat([data_aug, data_sep]).reset_index(drop=True)
# Out:
#                              started_at                         ended_at  \
# 0      2022-08-01 03:08:45.036000+00:00 2022-08-01 03:11:38.571000+00:00
# 1      2022-08-01 03:09:05.419000+00:00 2022-08-01 03:18:15.885000+00:00
# 2      2022-08-01 03:22:25.178000+00:00 2022-08-01 03:30:57.051000+00:00
# 3      2022-08-01 03:29:20.355000+00:00 2022-08-01 03:38:43.156000+00:00
# 4      2022-08-01 03:29:25.883000+00:00 2022-08-01 03:37:00.311000+00:00
# ...                                 ...                              ...
# 373205 2022-09-30 22:58:48.433000+00:00 2022-09-30 23:36:10.742000+00:00
# 373206 2022-09-30 22:59:04.940000+00:00 2022-09-30 23:10:24.031000+00:00
# 373207 2022-09-30 22:59:20.017000+00:00 2022-09-30 23:03:35.663000+00:00
# 373208 2022-09-30 22:59:41.280000+00:00 2022-09-30 23:07:23.601000+00:00
# 373209 2022-09-30 23:46:23.621000+00:00 2022-09-30 23:49:41.181000+00:00
#
#         duration  start_station_id         start_station_name  \
# 0            173               564                Oscars gate
# 1            550               421  Alexander Kiellands Plass
# 2            511               621           Torshovdalen øst
# 3            562               447                Kværnerbyen
# 4            454               421  Alexander Kiellands Plass
# ...          ...               ...                        ...
# 373205      2242               430           Spikersuppa Vest
# 373206       679               558                  Dokkveien
# 373207       255               424                Birkelunden
# 373208       462               421  Alexander Kiellands Plass
# 373209       197               428          Olav Kyrres plass
#
#            start_station_description  start_station_latitude  \
# 0                ved Hegdehaugsveien               59.922422
# 1                langs Maridalsveien               59.928067
# 2       ved Mailundveien rundkjøring               59.932857
# 3                langs Smeltedigelen               59.904473
# 4                langs Maridalsveien               59.928067
# ...                              ...                     ...
# 373205          ved Nasjonalteateret               59.913720
# 373206               ved Støperigata               59.910974
# 373207            langs Seilduksgata               59.925611
# 373208           langs Maridalsveien               59.928067
# 373209  ved den sveitsiske ambassade               59.919334
#
#         start_station_longitude  end_station_id    end_station_name  \
# 0                     10.727239             511  Henrik Ibsens gate
# 1                     10.751203             408         Tøyen skole
# 2                     10.777633             495    Vaterlandsparken
# 3                     10.786167             475       Hausmanns bru
# 4                     10.751203             557           Akersgata
# ...                         ...             ...                 ...
# 373205                10.735887             479          Tjuvholmen
# 373206                10.727700             597         Fredensborg
# 373207                10.760926             744        Hallénparken
# 373208                10.751203             469  Studentparlamentet
# 373209                10.696895             429               Thune
#
#           end_station_description  end_station_latitude  end_station_longitude
# 0                   ved Parkveien             59.915088              10.722280
# 1         forsiden av skolebygget             59.914943              10.773977
# 2                   langs Brugata             59.913516              10.757335
# 3              langs Nylandsveien             59.914651              10.759872
# 4                     ved Grensen             59.914197              10.742883
# ...                           ...                   ...                    ...
# 373205           ved Bryggegangen             59.909467              10.722509
# 373206          ved rundkjøringen             59.920995              10.750358
# 373207             ved Vogts gate             59.931530              10.762169
# 373208  ved Frydenlund holdeplass             59.920852              10.733357
# 373209              ved bomringen             59.922080              10.685880
#
# [373210 rows x 13 columns]

# %%
for filnavn in ["../data/08.csv", "../data/09.csv"]:
    print(filnavn)
# Out:
# ../data/08.csv
# ../data/09.csv

# %%
for filnavn in ["../data/08.csv", "../data/09.csv"]:
    print(filnavn)
    data = pd.read_csv(filnavn, parse_dates=["started_at", "ended_at"])
# Out:
# ../data/08.csv
# ../data/09.csv

# %%
data.started_at
# Out:
# 0        2022-09-01 03:04:31.178000+00:00
# 1        2022-09-01 03:11:09.104000+00:00
# 2        2022-09-01 03:11:37.861000+00:00
# 3        2022-09-01 03:13:00.843000+00:00
# 4        2022-09-01 03:13:13.330000+00:00
#                        ...
# 165872   2022-09-30 22:58:48.433000+00:00
# 165873   2022-09-30 22:59:04.940000+00:00
# 165874   2022-09-30 22:59:20.017000+00:00
# 165875   2022-09-30 22:59:41.280000+00:00
# 165876   2022-09-30 23:46:23.621000+00:00
# Name: started_at, Length: 165877, dtype: datetime64[ns, UTC]

# %%
months = []
for filnavn in ["../data/08.csv", "../data/09.csv"]:
    print(filnavn)
    months.append(pd.read_csv(filnavn, parse_dates=["started_at", "ended_at"]))
# Out:
# ../data/08.csv
# ../data/09.csv

# %%
months
# Out:
# [                             started_at                         ended_at  \
#  0      2022-08-01 03:08:45.036000+00:00 2022-08-01 03:11:38.571000+00:00
#  1      2022-08-01 03:09:05.419000+00:00 2022-08-01 03:18:15.885000+00:00
#  2      2022-08-01 03:22:25.178000+00:00 2022-08-01 03:30:57.051000+00:00
#  3      2022-08-01 03:29:20.355000+00:00 2022-08-01 03:38:43.156000+00:00
#  4      2022-08-01 03:29:25.883000+00:00 2022-08-01 03:37:00.311000+00:00
#  ...                                 ...                              ...
#  207328 2022-08-31 22:54:35.284000+00:00 2022-08-31 23:07:41.490000+00:00
#  207329 2022-08-31 22:55:19.669000+00:00 2022-08-31 22:59:49.689000+00:00
#  207330 2022-08-31 22:57:07.842000+00:00 2022-08-31 23:10:13.435000+00:00
#  207331 2022-08-31 22:59:08.604000+00:00 2022-08-31 23:11:39.844000+00:00
#  207332 2022-08-31 22:59:13.566000+00:00 2022-08-31 23:06:25.262000+00:00
#
#          duration  start_station_id         start_station_name  \
#  0            173               564                Oscars gate
#  1            550               421  Alexander Kiellands Plass
#  2            511               621           Torshovdalen øst
#  3            562               447                Kværnerbyen
#  4            454               421  Alexander Kiellands Plass
#  ...          ...               ...                        ...
#  207328       786               427                   Briskeby
#  207329       270               489                   Torggata
#  207330       785               585                Nordre gate
#  207331       751              2308                   Gunerius
#  207332       431               623            7. juni-plassen
#
#             start_station_description  start_station_latitude  \
#  0                ved Hegdehaugsveien               59.922422
#  1                langs Maridalsveien               59.928067
#  2       ved Mailundveien rundkjøring               59.932857
#  3                langs Smeltedigelen               59.904473
#  4                langs Maridalsveien               59.928067
#  ...                              ...                     ...
#  207328         ved Uranienborg skole               59.920218
#  207329         ved Bernt Ankers gate               59.915983
#  207330                ved Grünerbrua               59.921150
#  207331           utenfor Storgata 33               59.914599
#  207332      langs Henrik Ibsens gate               59.915060
#
#          start_station_longitude  end_station_id    end_station_name  \
#  0                     10.727239             511  Henrik Ibsens gate
#  1                     10.751203             408         Tøyen skole
#  2                     10.777633             495    Vaterlandsparken
#  3                     10.786167             475       Hausmanns bru
#  4                     10.751203             557           Akersgata
#  ...                         ...             ...                 ...
#  207328                10.717978             385         Søndre gate
#  207329                10.751551             551     Olaf Ryes plass
#  207330                10.754714             485     Sommerfrydhagen
#  207331                10.753399             485     Sommerfrydhagen
#  207332                10.731272             435         Fram-gården
#
#          end_station_description  end_station_latitude  end_station_longitude
#  0                 ved Parkveien             59.915088              10.722280
#  1       forsiden av skolebygget             59.914943              10.773977
#  2                 langs Brugata             59.913516              10.757335
#  3            langs Nylandsveien             59.914651              10.759872
#  4                   ved Grensen             59.914197              10.742883
#  ...                         ...                   ...                    ...
#  207328            ved Ankerbrua             59.918632              10.757867
#  207329     langs Sofienberggata             59.922425              10.758182
#  207330  langs Jens Bjelkes gate             59.911453              10.776072
#  207331  langs Jens Bjelkes gate             59.911453              10.776072
#  207332        langs Bygdøy Allé             59.915424              10.714577
#
#  [207333 rows x 13 columns],
#                               started_at                         ended_at  \
#  0      2022-09-01 03:04:31.178000+00:00 2022-09-01 03:13:01.298000+00:00
#  1      2022-09-01 03:11:09.104000+00:00 2022-09-01 03:14:52.506000+00:00
#  2      2022-09-01 03:11:37.861000+00:00 2022-09-01 03:23:23.939000+00:00
#  3      2022-09-01 03:13:00.843000+00:00 2022-09-01 03:17:17.639000+00:00
#  4      2022-09-01 03:13:13.330000+00:00 2022-09-01 03:24:15.758000+00:00
#  ...                                 ...                              ...
#  165872 2022-09-30 22:58:48.433000+00:00 2022-09-30 23:36:10.742000+00:00
#  165873 2022-09-30 22:59:04.940000+00:00 2022-09-30 23:10:24.031000+00:00
#  165874 2022-09-30 22:59:20.017000+00:00 2022-09-30 23:03:35.663000+00:00
#  165875 2022-09-30 22:59:41.280000+00:00 2022-09-30 23:07:23.601000+00:00
#  165876 2022-09-30 23:46:23.621000+00:00 2022-09-30 23:49:41.181000+00:00
#
#          duration  start_station_id         start_station_name  \
#  0            510               437              Sentrum Scene
#  1            223               578              Hallings gate
#  2            706               421  Alexander Kiellands Plass
#  3            256               735              Oslo Hospital
#  4            662               525              Myraløkka Øst
#  ...          ...               ...                        ...
#  165872      2242               430           Spikersuppa Vest
#  165873       679               558                  Dokkveien
#  165874       255               424                Birkelunden
#  165875       462               421  Alexander Kiellands Plass
#  165876       197               428          Olav Kyrres plass
#
#             start_station_description  start_station_latitude  \
#  0       ved Arbeidersamfunnets plass               59.915468
#  1                langs Dalsbergstien               59.922777
#  2                langs Maridalsveien               59.928067
#  3                  ved trikkestoppet               59.903213
#  4                    ved Bentsenbrua               59.937205
#  ...                              ...                     ...
#  165872          ved Nasjonalteateret               59.913720
#  165873               ved Støperigata               59.910974
#  165874            langs Seilduksgata               59.925611
#  165875           langs Maridalsveien               59.928067
#  165876  ved den sveitsiske ambassade               59.919334
#
#          start_station_longitude  end_station_id      end_station_name  \
#  0                     10.751141             583             Galgeberg
#  1                     10.738655             499     Bjerregaards gate
#  2                     10.751203             390             Saga Kino
#  3                     10.767344             465              Bjørvika
#  4                     10.760581             443  Sjøsiden ved trappen
#  ...                         ...             ...                   ...
#  165872                10.735887             479            Tjuvholmen
#  165873                10.727700             597           Fredensborg
#  165874                10.760926             744          Hallénparken
#  165875                10.751203             469    Studentparlamentet
#  165876                10.696895             429                 Thune
#
#               end_station_description  end_station_latitude  \
#  0            langs St. Halvards gate             59.907076
#  1       ovenfor Fredrikke Qvams gate             59.925488
#  2                 langs Olav Vs gate             59.914240
#  3           under broen Nylandsveien             59.909006
#  4                             Oslo S             59.910154
#  ...                              ...                   ...
#  165872              ved Bryggegangen             59.909467
#  165873             ved rundkjøringen             59.920995
#  165874                ved Vogts gate             59.931530
#  165875     ved Frydenlund holdeplass             59.920852
#  165876                 ved bomringen             59.922080
#
#          end_station_longitude
#  0                   10.779164
#  1                   10.746058
#  2                   10.732771
#  3                   10.756180
#  4                   10.751981
#  ...                       ...
#  165872              10.722509
#  165873              10.750358
#  165874              10.762169
#  165875              10.733357
#  165876              10.685880
#
#  [165877 rows x 13 columns]]

# %%
months = []
for filnavn in ["../data/08.csv", "../data/09.csv"]:
    print(filnavn)
    months.append(pd.read_csv(filnavn, parse_dates=["started_at", "ended_at"]))
data = pd.concat(months).reset_index(drop=True)
# Out:
# ../data/08.csv
# ../data/09.csv

# %%
data
# Out:
#                              started_at                         ended_at  \
# 0      2022-08-01 03:08:45.036000+00:00 2022-08-01 03:11:38.571000+00:00
# 1      2022-08-01 03:09:05.419000+00:00 2022-08-01 03:18:15.885000+00:00
# 2      2022-08-01 03:22:25.178000+00:00 2022-08-01 03:30:57.051000+00:00
# 3      2022-08-01 03:29:20.355000+00:00 2022-08-01 03:38:43.156000+00:00
# 4      2022-08-01 03:29:25.883000+00:00 2022-08-01 03:37:00.311000+00:00
# ...                                 ...                              ...
# 373205 2022-09-30 22:58:48.433000+00:00 2022-09-30 23:36:10.742000+00:00
# 373206 2022-09-30 22:59:04.940000+00:00 2022-09-30 23:10:24.031000+00:00
# 373207 2022-09-30 22:59:20.017000+00:00 2022-09-30 23:03:35.663000+00:00
# 373208 2022-09-30 22:59:41.280000+00:00 2022-09-30 23:07:23.601000+00:00
# 373209 2022-09-30 23:46:23.621000+00:00 2022-09-30 23:49:41.181000+00:00
#
#         duration  start_station_id         start_station_name  \
# 0            173               564                Oscars gate
# 1            550               421  Alexander Kiellands Plass
# 2            511               621           Torshovdalen øst
# 3            562               447                Kværnerbyen
# 4            454               421  Alexander Kiellands Plass
# ...          ...               ...                        ...
# 373205      2242               430           Spikersuppa Vest
# 373206       679               558                  Dokkveien
# 373207       255               424                Birkelunden
# 373208       462               421  Alexander Kiellands Plass
# 373209       197               428          Olav Kyrres plass
#
#            start_station_description  start_station_latitude  \
# 0                ved Hegdehaugsveien               59.922422
# 1                langs Maridalsveien               59.928067
# 2       ved Mailundveien rundkjøring               59.932857
# 3                langs Smeltedigelen               59.904473
# 4                langs Maridalsveien               59.928067
# ...                              ...                     ...
# 373205          ved Nasjonalteateret               59.913720
# 373206               ved Støperigata               59.910974
# 373207            langs Seilduksgata               59.925611
# 373208           langs Maridalsveien               59.928067
# 373209  ved den sveitsiske ambassade               59.919334
#
#         start_station_longitude  end_station_id    end_station_name  \
# 0                     10.727239             511  Henrik Ibsens gate
# 1                     10.751203             408         Tøyen skole
# 2                     10.777633             495    Vaterlandsparken
# 3                     10.786167             475       Hausmanns bru
# 4                     10.751203             557           Akersgata
# ...                         ...             ...                 ...
# 373205                10.735887             479          Tjuvholmen
# 373206                10.727700             597         Fredensborg
# 373207                10.760926             744        Hallénparken
# 373208                10.751203             469  Studentparlamentet
# 373209                10.696895             429               Thune
#
#           end_station_description  end_station_latitude  end_station_longitude
# 0                   ved Parkveien             59.915088              10.722280
# 1         forsiden av skolebygget             59.914943              10.773977
# 2                   langs Brugata             59.913516              10.757335
# 3              langs Nylandsveien             59.914651              10.759872
# 4                     ved Grensen             59.914197              10.742883
# ...                           ...                   ...                    ...
# 373205           ved Bryggegangen             59.909467              10.722509
# 373206          ved rundkjøringen             59.920995              10.750358
# 373207             ved Vogts gate             59.931530              10.762169
# 373208  ved Frydenlund holdeplass             59.920852              10.733357
# 373209              ved bomringen             59.922080              10.685880
#
# [373210 rows x 13 columns]

# %%
import pathlib

pathlib.Path.cwd().parent / "data"
# Out:
# PosixPath('/home/gahjelle/Dropbox/jobb/goto_hjelle/kurs/ffi/intro_data_processing/data')

# %%
(pathlib.Path.cwd().parent / "data").glob("*.csv")
# Out:
# <generator object Path.glob at 0x7f9724a8f220>

# %%
list((pathlib.Path.cwd().parent / "data").glob("*.csv"))
# Out:
# [PosixPath('/home/gahjelle/Dropbox/jobb/goto_hjelle/kurs/ffi/intro_data_processing/data/08.csv'),
#  PosixPath('/home/gahjelle/Dropbox/jobb/goto_hjelle/kurs/ffi/intro_data_processing/data/09.csv')]

# %%
months = []
for filnavn in ["../data/08.csv", "../data/09.csv"]:
    print(filnavn)
    months.append(pd.read_csv(filnavn, parse_dates=["started_at", "ended_at"]))
data = pd.concat(months).reset_index(drop=True)
# Out:
# ../data/08.csv
# ../data/09.csv

# %% [markdown]
# ### Exercise

# %% [markdown]
# ### Join tables with common variables

# %%
num_trips
# Out:
#             start_station_name  num_trips
# 233         Tordenskiolds gate         44
# 78              Gaustad T-bane         58
# 74                    Furulund         72
# 127               Kværnerveien         74
# 81                 Grenseveien         84
# ..                         ...        ...
# 160            Olaf Ryes plass       1918
# 175               Ringnes Park       1970
# 96       Helga Helgesens plass       1984
# 3                  Aker Brygge       2079
# 6    Alexander Kiellands Plass       2133
#
# [263 rows x 2 columns]

# %%
trip_lengths = (
    trips.groupby("start_station_name")
    .agg({"duration": "median"})
    .reset_index()
    .sort_values(by="duration")
)
trip_lengths
# Out:
#         start_station_name  duration
# 129              Lakkegata     345.0
# 93           Hausmanns bru     354.0
# 109         Jarlsborgveien     368.0
# 125  Krohgstøtten hospital     377.5
# 150          Meltzers gate     378.0
# ..                     ...       ...
# 74                Furulund    1244.0
# 157      Norsk Folkemuseum    1388.5
# 103                  Huk 1    1472.5
# 104                  Huk 2    1620.0
# 149        Maritimt Museum    1818.0
#
# [263 rows x 2 columns]

# %% [markdown]
# ### Exercise

# %% [markdown]
# ## Sharing Insights

# %% [markdown]
# ### Mess up data for presentation

# %% [markdown]
# ### Save to Excel

# %% [markdown]
# ### More visualizations
